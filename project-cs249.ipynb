# %%
p="/Users/user/Documents/cs249/train.txt"

# %%
import pandas as pd
data = pd.read_csv(p, sep="\t")

# %%
import numpy
from bert_serving.client import BertClient
bc = BertClient(check_length=False)

# %%
data
# Out:
#           id                                              turn1  \
# 0          0                              Don't worry  I'm girl
# 1          1                                        When did I?
# 2          2                                                 By
# 3          3                                     U r ridiculous
# 4          4                                 Just for time pass
# 5          5                                   I'm a dog person
# 6          6                                         So whatsup
# 7          7                                                 Ok
# 8          8                                            Really?
# 9          9                                                Bay
# 10        10                                I hate my boyfriend
# 11        11                                   I will do night.
# 12        12                                      Sure go ahead
# 13        13                                                Bad
# ...

# %%
x1=[]
x2=[]
x3=[]
y=[]
labels={}
i=0
for ind, row in data.iterrows():
    if row['label'] not in labels:
        labels[row['label']]=i
        i+=1
    y.append(labels[row['label']])
    x1.append(row['turn1'])
    x2.append(row['turn2'])
    x3.append(row['turn3'])

# %%
x1_vec=bc.encode(x1)
x2_vec=bc.encode(x2)
x3_vec=bc.encode(x3)

# %%
len(x1_vec)
# Out:
# 30160

# %%
import sklearn as sk 
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state=0).fit(x1_vec[0:27000], y[0:27000])

# %%
LR.predict(x1_vec[27000:])  
round(LR.score(x1_vec[27000:],y[27000:]), 4)
# Out:
# 0.607
