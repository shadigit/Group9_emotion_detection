# %%
import numpy as np
import pandas as pd
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons
import matplotlib.pyplot as plt
import emoji

from sys import path as pylib #im naming it as pylib so that we won't get confused between os.path and sys.path 
import os
pylib += [os.path.abspath(r'/home/Jay/Notebooks/Group9_emotion_detection/torchMoji')]

# %%
data = pd.read_csv('../../deepmoji/data/train.txt', sep = '\t')

# %%
label2emotion = {0: "others", 1: "happy", 2: "sad", 3: "angry"}
emotion2label = {"others": 0, "happy": 1, "sad": 2, "angry": 3}

emoticons_additional = {
    '(^・^)': '<happy>', ':‑c': '<sad>', '=‑d': '<happy>', ":'‑)": '<happy>', ':‑d': '<laugh>',
    ':‑(': '<sad>', ';‑)': '<happy>', ':‑)': '<happy>', ':\\/': '<sad>', 'd=<': '<annoyed>',
    ':‑/': '<annoyed>', ';‑]': '<happy>', '(^�^)': '<happy>', 'angru': 'angry', "d‑':":
        '<annoyed>', ":'‑(": '<sad>', ":‑[": '<annoyed>', '(�?�)': '<happy>', 'x‑d': '<laugh>',
}

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['url', 'email', 'percent', 'money', 'phone', 'user',
               'time', 'url', 'date', 'number'],
    # terms that will be annotated
    annotate={"hashtag", "allcaps", "elongated", "repeated",
              'emphasis', 'censored'},
    fix_html=True,  # fix HTML tokens
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter",
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter",
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=True,  # spell correction for elongated words
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons, emoticons_additional]
)


def tokenize(text):
    text = " ".join(text_processor.pre_process_doc(text))
    return text
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
x1=[]
x2=[]
x3=[]
y=[]
labels={}
i=0
for ind, row in data.iterrows():
    if row['label'] not in labels:
        labels[row['label']]=i
        i+=1
    y.append(labels[row['label']])
    x1.append(tokenize(row['turn1']))
    x2.append(tokenize(row['turn2']))
    x3.append(tokenize(row['turn3']))

# %%
test_data = pd.read_csv('../../deepmoji/data/test.txt', sep = '\t')
test_x1=[]
test_x2=[]
test_x3=[]
test_y=[]
test_labels={}
i=0
for ind, row in test_data.iterrows():
    if row['label'] not in test_labels:
        test_labels[row['label']]=i
        i+=1
    test_y.append(test_labels[row['label']])
    test_x1.append(tokenize(row['turn1']))
    test_x2.append(tokenize(row['turn2']))
    test_x3.append(tokenize(row['turn3']))

# %%
from __future__ import print_function, division, unicode_literals
import json

from torchmoji.sentence_tokenizer import SentenceTokenizer
from torchmoji.model_def import torchmoji_feature_encoding
from torchmoji.model_def import torchmoji_emojis
from torchmoji.global_variables import PRETRAINED_PATH, VOCAB_PATH

def encode_emoji(x):
    model = torchmoji_emojis(PRETRAINED_PATH)
    maxlen = 30
    batch_size = 32

    print('Tokenizing using dictionary from {}'.format(VOCAB_PATH))
    with open(VOCAB_PATH, 'r') as f:
        vocabulary = json.load(f)
    st = SentenceTokenizer(vocabulary, maxlen)
    tokenized, _, _ = st.tokenize_sentences(x)
    print('Loading model from {}.'.format(PRETRAINED_PATH))
    print(model)
    print('Running predictions.')
    
    encoding = np.zeros((len(x), 64))
    for i in range(0, len(x), 300):    
        encoding[i:i+300] = model(tokenized[i:i+300])
    return encoding

# %%
y=np.array(y)
idx_others=np.where(y==0)[0]
x1 = np.array(x1)
x2 = np.array(x2)
x3 = np.array(x3)

# %%
x_all = np.c_[x1,x2,x3]
x_all = np.array([' <eos> \n '.join(x) for x in x_all])

# %%
x_emoji = encode_emoji(x_all)
# Out:
# Tokenizing using dictionary from /home/Jay/Notebooks/Group9_emotion_detection/torchMoji/model/vocabulary.json
# Loading model from /home/Jay/Notebooks/Group9_emotion_detection/torchMoji/model/pytorch_model.bin.
# TorchMoji(
#   (embed): Embedding(50000, 256)
#   (embed_dropout): Dropout2d(p=0)
#   (lstm_0): LSTMHardSigmoid(256, 512, batch_first=True, bidirectional=True)
#   (lstm_1): LSTMHardSigmoid(1024, 512, batch_first=True, bidirectional=True)
#   (attention_layer): Attention(2304, return attention=False)
#   (final_dropout): Dropout(p=0)
#   (output_layer): Sequential(
#     (0): Linear(in_features=2304, out_features=64, bias=True)
#     (1): Softmax()
#   )
# )
# Running predictions.

# %%
import pickle
pickle.dump(x_emoji, open("../../deepmoji/data/emoji_predictions_concat.bin","wb"))

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

def metric(kmeans,dataset):    
    homogeneity, completeness, v_measure = metrics.homogeneity_completeness_v_measure(dataset.target, kmeans.labels_)
    rand_score = metrics.adjusted_rand_score(dataset.target, kmeans.labels_)
    mutual_info = metrics.adjusted_mutual_info_score(dataset.target, kmeans.labels_)
    print(metrics.cluster.contingency_matrix(kmeans.labels_, dataset.target))
    plot_contingency_table(metrics.cluster.contingency_matrix(kmeans.labels_, dataset.target))
    print("Homogeneity Score: %0.5f"%homogeneity)
    print("Completeness Score: %0.5f"%completeness)
    print("V-measure: %0.5f"%v_measure)
    print("Adjusted Rand Score: %0.5f"%rand_score)
    print("Adjusted Mutual Information Score: %0.5f"%mutual_info)
    return [homogeneity, completeness, v_measure, rand_score, mutual_info]

# %%
from matplotlib import pyplot as plt

def plot_clusters(data, labels, centroids=None, x1=0,x2=1):
  cluster_colors = {8:'#222222', 1: '#461ff4', 2:'#FF3333',  # red
                   3:'#0198E1',  # blue
                   4:'#BF5FFF',  # purple
                   5:'#FCD116',  # yellow
                   6:'#FF7216',  # orange
                   7:'#4DBD33',  # green
                   0:'#87421F'   # brown
                   }
  color_arr = [cluster_colors[i%len(cluster_colors)] for i in labels]
  plt.figure(figsize=(20,8))
  plt.grid(False)
  plt.scatter(data[:,x1], data[:,x2], c= color_arr, alpha=0.75)
  if centroids is not None:
    plt.scatter(centroids[:, 0], centroids[:, 1],marker='x', c='black')
    plt.show()

# %%
x_emoji_others = x_emoji[np.where(data['label']=='others')[0]]

# %%
x_emoji_others.shape
# Out:
# (14948, 64)

# %%
kmeans=[]
for i in range(2,50,2):
    print("KMeans with cluster size ",i)
    kmeans.append(KMeans(n_clusters=i, init='k-means++', n_init=50, max_iter=1500, random_state=0).fit(x_emoji_others))
    print(kmeans[-1].inertia_)
    #plot_clusters(x_emoji, kmeans[-1].predict(x_emoji), kmeans[-1].cluster_centers_)
# Out:
# KMeans with cluster size  2
# 210.4391215989133
# KMeans with cluster size  4
# 131.54645005260156
# KMeans with cluster size  6
# 106.45074077728674
# KMeans with cluster size  8
# 93.16603681886771
# KMeans with cluster size  10
# 83.77541437786807
# KMeans with cluster size  12
# 78.08318568259838
# KMeans with cluster size  14
# 73.81063509198513
# KMeans with cluster size  16
# 70.15147526966338
# KMeans with cluster size  18
# 67.42865987421474
# KMeans with cluster size  20
# 65.06785017523329
# KMeans with cluster size  22
# 63.00422369763809
# KMeans with cluster size  24
# 61.1836427908112
# KMeans with cluster size  26
# 59.66061224527016
# KMeans with cluster size  28
# 58.377113562583915
# KMeans with cluster size  30
# 57.059973404187026
# KMeans with cluster size  32
# 55.919518854751864
# KMeans with cluster size  34
# ---------------------------------------------------------------------------
# ...

# %%
ssd = []
for km in kmeans:
    ssd.append(km.inertia_)

# %%
range(2,len(ssd),2)
# Out:
# range(2, 16, 2)

# %%
plt.plot(range(2,34,2), ssd,'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
dim = 2
pca = PCA(n_components = dim)
x_reduced =pca.fit_transform(x_emoji_others)
print("Explained Variance - ",pca.explained_variance_ratio_)
# Out:
# Explained Variance -  [0.41537302 0.38233795]

# %%
for k in [5,6,7,8]:
    k_red = KMeans(n_clusters=k, init='k-means++', n_init=50, max_iter=1500, random_state=0).fit(x_reduced)
    print("For cluster with ",k," clusters")
    plot_clusters(x_reduced, k_red.predict(x_reduced), k_red.cluster_centers_)
# Out:
# For cluster with  5  clusters
# For cluster with  6  clusters
# For cluster with  7  clusters
# For cluster with  8  clusters

# %%
x1_emoji = encode_emoji(x1)
x2_emoji = encode_emoji(x2)
x3_emoji = encode_emoji(x3)

# %%
def top_elements(array, k):
    ind = np.argpartition(array, -k)[-k:]
    return ind[np.argsort(array[ind])][::-1]

EMOJIS = ":joy: :unamused: :weary: :sob: :heart_eyes: \
:pensive: :ok_hand: :blush: :heart: :smirk: \
:grin: :notes: :flushed: :100: :sleeping: \
:relieved: :relaxed: :raised_hands: :two_hearts: :expressionless: \
:sweat_smile: :pray: :confused: :kissing_heart: :heartbeat: \
:neutral_face: :information_desk_person: :disappointed: :see_no_evil: :tired_face: \
:v: :sunglasses: :rage: :thumbsup: :cry: \
:sleepy: :yum: :triumph: :hand: :mask: \
:clap: :eyes: :gun: :persevere: :smiling_imp: \
:sweat: :broken_heart: :yellow_heart: :musical_note: :speak_no_evil: \
:wink: :skull: :confounded: :smile: :stuck_out_tongue_winking_eye: \
:angry: :no_good: :muscle: :facepunch: :purple_heart: \
:sparkling_heart: :blue_heart: :grimacing: :sparkles:".split(' ')

# %%
turn1=[]
turn2=[]
turn3=[]

for i, text in enumerate(data['turn1'].values):
    emoji_ids = top_elements(x1_emoji[i], 5)
    emojis = map(lambda x: EMOJIS[x], emoji_ids)
    turn1.append(emoji.emojize("{} {}".format(text,' '.join(emojis)), use_aliases=True))

for i, text in enumerate(data['turn2'].values):
    emoji_ids = top_elements(x2_emoji[i], 5)
    emojis = map(lambda x: EMOJIS[x], emoji_ids)
    turn2.append(emoji.emojize("{} {}".format(text,' '.join(emojis)), use_aliases=True))

for i, text in enumerate(data['turn3'].values):
    emoji_ids = top_elements(x3_emoji[i], 5)
    emojis = map(lambda x: EMOJIS[x], emoji_ids)
    turn3.append(emoji.emojize("{} {}".format(text,' '.join(emojis)), use_aliases=True))
    #print(emoji.emojize("{} {}".format(x1[i],' '.join(emojis)), use_aliases=True))

data['turn1'] = turn1
data['turn2'] = turn2
data['turn3'] = turn3

# %%
labels = []
for i, prob in enumerate(x_emoji):
    emoji_ids = top_elements(prob, 5)
    emojis = map(lambda x: EMOJIS[x], emoji_ids)
    labels.append(emoji.emojize(' '.join(emojis), use_aliases=True))
    
data['label_emo'] = labels

# %%
data
# Out:
#           id                                              turn1  \
# 0          0                              Don't worry  I'm girl
# 1          1                                        When did I?
# 2          2                                                 By
# 3          3                                     U r ridiculous
# 4          4                                 Just for time pass
# 5          5                                   I'm a dog person
# 6          6                                         So whatsup
# 7          7                                                 Ok
# 8          8                                            Really?
# 9          9                                                Bay
# 10        10                                I hate my boyfriend
# 11        11                                   I will do night.
# 12        12                                      Sure go ahead
# 13        13                                                Bad
# ...

# %%
data_others = data[data['label']=='others']

# %%
len(data_others)
# Out:
# 14948

# %%
def display_clusters(data_others, k):
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=50, max_iter=1500, random_state=0).fit(x_reduced)
    data_others['cluster'] = kmeans.predict(x_reduced)
    c_gps = data_others.groupby(by='cluster')
    agg=c_gps.agg({'label':'count','label_emo':''.join})
    agg['label_emo'] = agg['label_emo'].apply(set)
    agg['count'] = agg['label_emo'].apply(len)
    
    
    diff_dict = []
    emoji_sets = agg['label_emo'].values
    emoji_mean=[]
    for i in range(len(emoji_sets)):
        diff_dict.append({'total':len(emoji_sets[i])})
        emoji_ids = top_elements(pca.inverse_transform(kmeans.cluster_centers_[i]), 20)
        emojis = map(lambda x: EMOJIS[x], emoji_ids)
        emoji_mean.append(emoji.emojize(' '.join(emojis), use_aliases=True))
        for j in range(0,len(emoji_sets)):
            #st1 = str(i)+'-'+str(j)
            #diff_dict[i][j] = len(emoji_sets[i]-emoji_sets[j])
            diff_dict[i][j] = (str(len(emoji_sets[i]-emoji_sets[j]))+' - ')+''.join(emoji_sets[i]-emoji_sets[j])
    
    agg['mean_emoji'] = emoji_mean
    return agg, pd.DataFrame(diff_dict)

# %%
agg, diff_dict = display_clusters(data_others, 6)
# Out:
# /home/Jay/dev32/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
agg
# Out:
#                                                  label_emo  label  count  \
# cluster
# 0        {💖, 🎶, 💁, 😊, 😖, 🎵, 💪, 🙏,  , 👏, 👍, 😢, 😪, 💯, 😣, ...   3583     45
# 1        {😡, 💖, 😅, 🎶, 😖, 😊, 💕, 💁, 🎵, 💪, 🙏, 😓,  , 👏, 👍, ...   2881     57
# 2        {😡, 🎶, 😊, 🎵, 💪, 🙏,  , 👏, 👍, 😢, 😁, 😪, 💯, 💔, 💛, ...   1235     32
# 3        {🎶, 💕, 🎵, 💪, 🙏,  , 👏, 👍, 😪, 😢, 💯, 👌, 💀, 💔, 💛, ...   1408     32
# 4        {🎶, 😊, 🎵, 💪, 🙏,  , 👏, 👍, 😪, 😢, 💯, 👌, 💀, 💔, 💛, ...   2521     36
# 5        {😅, 🎶, 😖, 😊, 🎵, 💪, 🙏, 😓,  , 👏, 👍, 😢, 😪, 💯, 😣, ...   3320     44
#
#                                       mean_emoji
# cluster
# 0        💓 ☺ 💛 ✨ 🎶 🎵 ✌ 👍 😉 ❤ 👀 🙏 😄 💯 💔 😊 😜 ✋ 😎 👊
# 1        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 👀 😉 😄 🙏 💔 💯 😜 ✋ 😎 😊 👊 🔫
# 2        ☺ 💓 💛 😉 😄 ✨ ✌ 👍 😊 🙏 😜 👀 ❤ 🎶 😁 😎 🎵 ✋ 😌 💯
# 3        💓 💛 ☺ ✨ ❤ 🎶 🎵 ✌ 🙏 👍 😉 💜 😘 😄 💯 💖 💕 💙 😊 👌
# 4        💓 ☺ 💛 ✨ 🎶 ✌ 🎵 😉 ❤ 👍 😄 🙏 😊 👀 💯 😜 ✋ 😎 😁 👌
# 5        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 😉 😄 👀 🙏 😊 😜 ❤ 💯 😎 ✋ 💔 👊

# %%
diff_dict
# Out:
#                     0      1                                2  \
# 0                0 -   1 - 😭             15 - 😈😘😖💁💜👌😣🙅💙💀🙊🙌💖😷😭
# 1  13 - 😡🙈😬😅😒💕😑😐😌😳😓😞😤   0 -   26 - 😅😖💁💕😓😬😒😣👌😑😐💀🙌🙈💜😳😞😘🙅💙🙊😌😈💖😷😤
# 2              2 - 😡😁  1 - 😁                             0 -
# 3              2 - 💕😍  1 - 😍                     8 - 😘💜👌💕💙💀💖😍
# 4                0 -    0 -                        6 - 😘👌💙💀🙊🙌
# 5          6 - 🙈😅😐😌😓😞   0 -               14 - 😘🙈😅😖👌😣🙅😐💀😌😓🙌😷😞
#
#                                  3                           4  \
# 0             15 - 😈✋😋😖💁😊😣🙅😕😎🙊🙌😜😷😭               9 - 😖💁💜😣🙅😈💖😷😭
# 1  26 - 😡😅😖💁😊😓😬😒😣😑😐🙌✋😋🙈😎😳😞😷🙅🙊😌😈😜😕😤  21 - 😡🙈😅😬😖💁😒💕😣💜🙅😑😐😌😳😓😈💖😷😞😤
# 2                     8 - 😡✋😁😋😊😎😜😕                      2 - 😡😁
# 3                             0 -                     4 - 💖💜💕😍
# 4                     8 - ✋😋😊😎🙊🙌😜😕                        0 -
# 5           17 - ✋😋🙈😅😖😊😣🙅😕😎😐😌😓🙌😜😷😞             10 - 🙈😅😖😣🙅😐😌😓😷😞
#
#                     5  total
# 0         7 - 💁💜💙🙊😈💖😭     45
# ...

# %%
agg, diff_dict = display_clusters(data_others, 8)
# Out:
# /home/Jay/dev32/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
agg
# Out:
#                                                  label_emo  label  count  \
# cluster
# 0        {💖, 🎶, 💁, 😊, 💕, 🎵, 💪, 🙏,  , 👏, 👍, 😢, 💯, 👌, 💀, ...   1717     37
# 1        {😅, 🎶, 😖, 😊, 🎵, 💪, 🙏, 😓,  , 👏, 👍, 😢, 😪, 💯, 👌, ...   2849     44
# 2        {🎶, 😊, 🎵, 💪, 🙏,  , 👏, 👍, 😪, 😢, 💯, 👌, 💀, 💔, 💛, ...   2168     34
# 3        {😡, 💖, 😅, 🎶, 😖, 😊, 💕, 💁, 🎵, 💪, 🙏, 😓,  , 👏, 👍, ...   2308     57
# 4        {🎶, 🎵, 🙏,  , 👏, 👍, 😪, 😢, 💯, 👌, 💔, 💛, ✨, 😍, 👀, ...    768     25
# 5        {💖, 🎶, 😖, 😊, 💁, 🎵, 💪, 🙏,  , 👏, 👍, 😢, 😪, 💯, 😣, ...   3033     45
# 6        {😡, 😅, 🎶, 😊, 🎵, 💪, 🙏, 😓,  , 👏, 👍, 😢, 😁, 😪, 💯, ...   1618     38
# 7        {🎶, 😊, 🎵, 💪, 🙏,  , 👍, 😢, 😁, 💯, 💔, 💛, ✨, ✋, 👊, ...    487     26
#
#                                       mean_emoji
# cluster
# 0        💓 💛 ☺ ✨ 🎶 🎵 ❤ ✌ 👍 😉 🙏 😄 👀 💯 😊 💔 💜 👌 😜 ✋
# 1        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 😉 😄 👀 🙏 😊 😜 💯 ❤ 😎 ✋ 💔 👊
# 2        💓 ☺ 💛 ✨ 🎶 ✌ 🎵 ❤ 😉 👍 🙏 😄 😊 👀 💯 😜 ✋ 😎 👌 😁
# 3        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 👀 😉 😄 💔 💯 🙏 😜 ✋ 😎 😊 👊 🔫
# ...

# %%
diff_dict
# Out:
#                             0                   1  \
# 0                        0 -           6 - 💁💜💕💙💖😭
# 1          13 - 😪🙈😅😖😣😕😎😐😌😓🙌😷😞                0 -
# 2                    4 - 😎😪😕🙊              2 - 💙🙊
# 3  21 - 😈😡😪🙈😬😅😖😷😒😣😑😐😎😳🙊😌😓🙌😕😞😤  13 - 😡😬💁😒💕💜😑💙🙊😳😈💖😤
# 4                      2 - 😪😍             3 - 💙💜😍
# 5             10 - 😈😪😖😣😕😎🙊🙌😷😞          6 - 💁💜💙🙊😈💖
# 6               9 - 😡😁😪😅😎😐😓🙌😕              2 - 😡😁
# 7                      2 - 😁😕               1 - 😁
#
#                               2      3  \
# 0                   7 - 💁💜💕🙅💖🔫😭  1 - 😭
# 1             12 - 🙈😅😷😖😣🙅😐😌😓🙌🔫😞   0 -
# 2                          0 -    0 -
# 3  23 - 😡😅😖💁💕😓😬😒😣😑😐🙌🔫🙈💜😳😞🙅😌😈💖😷😤   0 -
# 4                        2 - 💜😍  1 - 😍
# 5              11 - 😈😷😖💁💜😣🙅🙌💖🔫😞   0 -
# 6                   7 - 😡😁😅😐😓🙌🔫  1 - 😁
# 7                         1 - 😁  1 - 😁
#
#                                         4                  5  \
# 0                     14 - ✋👊😋💁😊💕🙅💪💀😠😜💖🔫😭             2 - 💕😭
# ...

# %%
agg, diff_dict = display_clusters(data_others, 7)
# Out:
# /home/Jay/dev32/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
agg
# Out:
#                                                  label_emo  label  count  \
# cluster
# 0        {😅, 🎶, 😖, 😊, 💁, 🎵, 💪, 🙏, 😓,  , 👏, 👍, 😢, 😪, 💯, ...   3262     45
# 1        {🎶, 💁, 😊, 🎵, 💪, 🙏,  , 👏, 👍, 😪, 😢, 💯, 💀, 💔, 💛, ...   2382     35
# 2        {😡, 💖, 😅, 🎶, 😖, 😊, 💕, 💁, 🎵, 💪, 🙏, 😓,  , 👏, 👍, ...   2600     57
# 3        {😡, 😅, 🎶, 😊, 🎵, 💪, 🙏, 😓,  , 👏, 👍, 😢, 😁, 😪, 💯, ...   1917     38
# 4        {💖, 🎶, 😖, 😊, 🎵, 💪, 🙏,  , 👏, 👍, 😢, 😪, 💯, 😣, 👌, ...   3145     44
# 5        {🎶, 💕, 🎵, 💪, 🙏,  , 👏, 👍, 😪, 😢, 💯, 👌, 💀, 💔, 💛, ...   1095     31
# 6        {🎶, 😊, 🎵, 💪, 🙏,  , 👍, 😢, 😁, 💯, 💔, 💛, ✨, ✋, 👊, ...    547     27
#
#                                       mean_emoji
# cluster
# 0        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 😉 😄 👀 🙏 😊 😜 ❤ 💯 😎 ✋ 💔 👊
# 1        💓 ☺ 💛 ✨ 🎶 🎵 ✌ ❤ 👍 😉 🙏 😄 😊 👀 💯 😜 ✋ 💜 👌 😎
# 2        ☺ 💓 💛 ✨ 🎶 🎵 ✌ 👍 👀 😉 😄 💔 🙏 💯 😜 ✋ 😎 😊 👊 🔫
# 3        ☺ 💓 💛 ✨ ✌ 😉 👍 😄 🎶 🎵 🙏 😊 ❤ 👀 😜 💯 😎 ✋ 😁 😌
# 4        💓 ☺ 💛 ✨ 🎶 🎵 ✌ 👍 😉 ❤ 👀 🙏 😄 💯 💔 😊 😜 ✋ 😎 👊
# 5        💓 💛 ☺ ✨ ❤ 🎶 🎵 ✌ 🙏 👍 😉 💜 😘 💯 💖 😄 💕 💙 👌 😊
# ...

# %%
diff_dict
# Out:
#                    0                            1      2  \
# 0               0 -             12 - 🙈😅😖😣👌🙅😐😌😓🙌😷😞   0 -
# 1             2 - 💙🙊                         0 -    0 -
# 2  12 - 😡😬😒💕💜😑💙🙊😳😈💖😤  22 - 😡😅😖💕😓😬😒😣👌😑😐🙌🙈💜😳😞🙅😌😈💖😷😤   0 -
# 3             2 - 😡😁                   6 - 😡😁😅😐😓🙌  1 - 😁
# 4         6 - 💜💙🙊😈💖😭              10 - 😈😖💜👌😣🙅🙌💖😷😭  1 - 😭
# 5          5 - 💙💖💜💕😍                    5 - 👌💜💕😍💖  1 - 😍
# 6              1 - 😁                        1 - 😁  1 - 😁
#
#                            3                    4  \
# 0              9 - 🙈😖💁👌😣🙅😌😷😞          7 - 🙈😅💁😐😌😓😞
# 1                    3 - 💙🙊💁                1 - 💁
# 2  20 - 🙈😬😖💁😒💕😣👌💜😑🙅💙😳🙊😌😈💖😷😞😤  14 - 😡🙈😬😅💁😒💕😑😐😌😳😓😞😤
# 3                       0 -             5 - 😡😁😐😓😅
# 4           11 - 😖💜👌😣🙅💙🙊😈💖😷😭                 0 -
# 5                 6 - 💜👌💕💙💖😍               2 - 💕😍
# 6                       0 -                 1 - 😁
#
#                                   5                                     6  \
# ...
